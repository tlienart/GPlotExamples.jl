# %%
using GPlot
# Out:
# ┌ Info: Recompiling stale cache file /Users/tlienart/.julia/compiled/v1.1/GPlot/3kxwE.ji for GPlot [761cd3e3-77fb-536d-8887-987003f9acc3]
# └ @ Base loading.jl:1184

# %%
f = Figure()

x1 = range(-2, stop=2, length=100)
y1 = @. exp(-x1 * sin(x1))
y2 = @. exp(-x1 * cos(x1))
x2 = range(0, stop=2, length=10)
y3 = @. sqrt(x2)
y4 = @. exp(sin(x1)-x1^2)*x1

plot!(x1, y1, color="darkblue", lwidth=0.02, lstyle=2)
plot!(x1, y2, color="indianred")
plot!(x2, y3, marker="fcircle", msize=0.1, color="#0c88c2")
plot!(x1, y4, color="#76116d", lwidth=0.1)

xtitle!("x-axis")
x2title!("x2-axis")
y2title!("y2-axis")
ytitle!("y-axis")
title!("The title")

preview(f)
# Out:
# GPlot.PreviewFigure(Figure{GPlot.GLE}("_fig_", GPlot.GLE(IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=0, maxsize=Inf, ptr=1, mark=-1)), GPlot.Axes{GPlot.GLE}[Axes2D{GLE}
#   xaxis: Axis
#   x2axis: Axis
#   yaxis: Axis
#   y2axis: Axis
#   drawings: Array{Drawing}((4,))
#   title: Title
#   size: Nothing nothing
#   math: Nothing nothing
#   legend: Nothing nothing
# ], (8.0, 6.0), GPlot.TextStyle
#   font: Nothing nothing
#   hei: Float64 0.2
#   color: Nothing nothing
# , nothing, nothing, nothing), "/Users/tlienart/.julia/dev/GPlotExamples.jl/tmp/_fig_.png")
